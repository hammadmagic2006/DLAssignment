# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD
from sklearn.preprocessing import LabelEncoder

# %%
# load dataset
data = pd.read_csv("/home/hammad/my_project_dir/ionosphere_data.csv",delimiter=",")

# %%
data.head()
# Out:
#    feature1  feature2  feature3  feature4  feature5  feature6  feature7  \
# 0         1         0   0.99539  -0.05889   0.85243   0.02306   0.83398
# 1         1         0   1.00000  -0.18829   0.93035  -0.36156  -0.10868
# 2         1         0   1.00000  -0.03365   1.00000   0.00485   1.00000
# 3         1         0   1.00000  -0.45161   1.00000   1.00000   0.71216
# 4         1         0   1.00000  -0.02401   0.94140   0.06531   0.92106
#
#    feature8  feature9  feature10  ...  feature26  feature27  feature28  \
# 0  -0.37708   1.00000    0.03760  ...   -0.51171    0.41078   -0.46168
# 1  -0.93597   1.00000   -0.04549  ...   -0.26569   -0.20468   -0.18401
# 2  -0.12062   0.88965    0.01198  ...   -0.40220    0.58984   -0.22145
# 3  -1.00000   0.00000    0.00000  ...    0.90695    0.51613    1.00000
# 4  -0.23255   0.77152   -0.16399  ...   -0.65158    0.13290   -0.53206
#
#    feature29  feature30  feature31  feature32  feature33  feature34  label
# 0    0.21266   -0.34090    0.42267   -0.54487    0.18641   -0.45300      g
# 1   -0.19040   -0.11593   -0.16626   -0.06288   -0.13738   -0.02447      b
# 2    0.43100   -0.17365    0.60436   -0.24180    0.56045   -0.38238      g
# 3    1.00000   -0.20099    0.25682    1.00000   -0.32382    1.00000      b
# 4    0.02431   -0.62197   -0.05707   -0.59573   -0.04608   -0.65697      g
#
# [5 rows x 35 columns]

# %%
# Print Missing value
print(data.isnull().sum())
# Out:
# feature1     0
# feature2     0
# feature3     0
# feature4     0
# feature5     0
# feature6     0
# feature7     0
# feature8     0
# feature9     0
# feature10    0
# feature11    0
# feature12    0
# feature13    0
# feature14    0
# feature15    0
# feature16    0
# feature17    0
# feature18    0
# feature19    0
# feature20    0
# feature21    0
# feature22    0
# feature23    0
# feature24    0
# feature25    0
# feature26    0
# feature27    0
# feature28    0
# feature29    0
# feature30    0
# feature31    0
# feature32    0
# feature33    0
# feature34    0
# label        0
# dtype: int64

# %%
# split into input (X) and output (Y) variables

X = data.values[1:,0:34].astype(float)
Y = data.values[1:,34]
# encode class values as integers
encoder = LabelEncoder()
encoder.fit(Y)
Y = encoder.transform(Y)

# %%
# create model
model = Sequential()
model.add(Dense(34, input_dim=34 , activation= 'relu' ))
model.add(Dense(1,  activation= 'sigmoid' ))

# %%
# Compile model
epochs = 50
learning_rate = 0.1
decay_rate = learning_rate / epochs
momentum = 0.8
sgd = SGD(lr=learning_rate, momentum=momentum, decay=decay_rate, nesterov=False)
model.compile(loss= 'binary_crossentropy' , optimizer=sgd, metrics=[ 'accuracy' ])

# %%
# Fit the model
model.fit(X, Y, validation_split=0.33, epochs=epochs, batch_size=8, verbose=2)
# Out:
# Epoch 1/50
# 30/30 - 1s - loss: 0.5307 - accuracy: 0.7350 - val_loss: 0.1335 - val_accuracy: 0.9655
# Epoch 2/50
# 30/30 - 0s - loss: 0.3009 - accuracy: 0.9017 - val_loss: 0.1024 - val_accuracy: 0.9828
# Epoch 3/50
# 30/30 - 0s - loss: 0.2122 - accuracy: 0.9145 - val_loss: 0.0876 - val_accuracy: 0.9741
# Epoch 4/50
# 30/30 - 0s - loss: 0.1803 - accuracy: 0.9274 - val_loss: 0.0778 - val_accuracy: 0.9914
# Epoch 5/50
# 30/30 - 0s - loss: 0.1516 - accuracy: 0.9530 - val_loss: 0.1458 - val_accuracy: 0.9483
# Epoch 6/50
# 30/30 - 0s - loss: 0.1211 - accuracy: 0.9658 - val_loss: 0.0701 - val_accuracy: 0.9828
# Epoch 7/50
# 30/30 - 0s - loss: 0.1027 - accuracy: 0.9701 - val_loss: 0.0612 - val_accuracy: 0.9828
# Epoch 8/50
# 30/30 - 0s - loss: 0.0914 - accuracy: 0.9701 - val_loss: 0.0541 - val_accuracy: 0.9914
# Epoch 9/50
# 30/30 - 0s - loss: 0.0992 - accuracy: 0.9658 - val_loss: 0.0883 - val_accuracy: 0.9828
# Epoch 10/50
# 30/30 - 0s - loss: 0.0823 - accuracy: 0.9829 - val_loss: 0.0912 - val_accuracy: 0.9828
# Epoch 11/50
# 30/30 - 0s - loss: 0.0913 - accuracy: 0.9744 - val_loss: 0.0530 - val_accuracy: 0.9914
# Epoch 12/50
# 30/30 - 0s - loss: 0.0735 - accuracy: 0.9786 - val_loss: 0.0601 - val_accuracy: 0.9914
# Epoch 13/50
# 30/30 - 0s - loss: 0.0653 - accuracy: 0.9829 - val_loss: 0.0602 - val_accuracy: 0.9914
# Epoch 14/50
# 30/30 - 0s - loss: 0.0641 - accuracy: 0.9829 - val_loss: 0.0570 - val_accuracy: 0.9914
# Epoch 15/50
# 30/30 - 0s - loss: 0.0642 - accuracy: 0.9829 - val_loss: 0.0591 - val_accuracy: 0.9914
# Epoch 16/50
# 30/30 - 0s - loss: 0.0575 - accuracy: 0.9829 - val_loss: 0.0651 - val_accuracy: 0.9914
# Epoch 17/50
# 30/30 - 0s - loss: 0.0602 - accuracy: 0.9872 - val_loss: 0.0517 - val_accuracy: 0.9914
# Epoch 18/50
# 30/30 - 0s - loss: 0.0531 - accuracy: 0.9829 - val_loss: 0.0508 - val_accuracy: 0.9914
# Epoch 19/50
# 30/30 - 0s - loss: 0.0520 - accuracy: 0.9829 - val_loss: 0.0600 - val_accuracy: 0.9914
# Epoch 20/50
# 30/30 - 0s - loss: 0.0515 - accuracy: 0.9829 - val_loss: 0.0529 - val_accuracy: 0.9914
# Epoch 21/50
# 30/30 - 0s - loss: 0.0483 - accuracy: 0.9872 - val_loss: 0.0528 - val_accuracy: 0.9914
# Epoch 22/50
# 30/30 - 0s - loss: 0.0475 - accuracy: 0.9872 - val_loss: 0.0426 - val_accuracy: 0.9914
# Epoch 23/50
# 30/30 - 0s - loss: 0.0468 - accuracy: 0.9872 - val_loss: 0.0651 - val_accuracy: 0.9914
# Epoch 24/50
# 30/30 - 0s - loss: 0.0507 - accuracy: 0.9872 - val_loss: 0.0529 - val_accuracy: 0.9914
# Epoch 25/50
# 30/30 - 0s - loss: 0.0420 - accuracy: 0.9872 - val_loss: 0.0439 - val_accuracy: 0.9914
# Epoch 26/50
# 30/30 - 0s - loss: 0.0434 - accuracy: 0.9872 - val_loss: 0.0529 - val_accuracy: 0.9914
# Epoch 27/50
# 30/30 - 0s - loss: 0.0409 - accuracy: 0.9872 - val_loss: 0.0479 - val_accuracy: 0.9914
# Epoch 28/50
# 30/30 - 0s - loss: 0.0399 - accuracy: 0.9872 - val_loss: 0.0679 - val_accuracy: 0.9828
# Epoch 29/50
# 30/30 - 0s - loss: 0.0402 - accuracy: 0.9915 - val_loss: 0.0475 - val_accuracy: 0.9914
# Epoch 30/50
# 30/30 - 0s - loss: 0.0386 - accuracy: 0.9915 - val_loss: 0.0434 - val_accuracy: 0.9914
# Epoch 31/50
# 30/30 - 0s - loss: 0.0396 - accuracy: 0.9872 - val_loss: 0.0522 - val_accuracy: 0.9914
# Epoch 32/50
# 30/30 - 0s - loss: 0.0400 - accuracy: 0.9915 - val_loss: 0.0579 - val_accuracy: 0.9914
# Epoch 33/50
# 30/30 - 0s - loss: 0.0369 - accuracy: 0.9872 - val_loss: 0.0514 - val_accuracy: 0.9914
# Epoch 34/50
# 30/30 - 0s - loss: 0.0360 - accuracy: 0.9957 - val_loss: 0.0487 - val_accuracy: 0.9914
# Epoch 35/50
# 30/30 - 0s - loss: 0.0357 - accuracy: 0.9915 - val_loss: 0.0572 - val_accuracy: 0.9914
# Epoch 36/50
# 30/30 - 0s - loss: 0.0384 - accuracy: 0.9915 - val_loss: 0.0583 - val_accuracy: 0.9914
# Epoch 37/50
# 30/30 - 0s - loss: 0.0348 - accuracy: 0.9957 - val_loss: 0.0498 - val_accuracy: 0.9914
# Epoch 38/50
# 30/30 - 0s - loss: 0.0349 - accuracy: 0.9915 - val_loss: 0.0492 - val_accuracy: 0.9914
# Epoch 39/50
# 30/30 - 0s - loss: 0.0344 - accuracy: 0.9915 - val_loss: 0.0512 - val_accuracy: 0.9914
# Epoch 40/50
# 30/30 - 0s - loss: 0.0333 - accuracy: 0.9915 - val_loss: 0.0587 - val_accuracy: 0.9914
# Epoch 41/50
# 30/30 - 0s - loss: 0.0326 - accuracy: 0.9957 - val_loss: 0.0453 - val_accuracy: 0.9914
# Epoch 42/50
# 30/30 - 0s - loss: 0.0350 - accuracy: 0.9915 - val_loss: 0.0454 - val_accuracy: 0.9914
# Epoch 43/50
# 30/30 - 0s - loss: 0.0337 - accuracy: 0.9957 - val_loss: 0.0434 - val_accuracy: 0.9914
# Epoch 44/50
# 30/30 - 0s - loss: 0.0330 - accuracy: 0.9957 - val_loss: 0.0513 - val_accuracy: 0.9914
# Epoch 45/50
# 30/30 - 0s - loss: 0.0312 - accuracy: 0.9915 - val_loss: 0.0478 - val_accuracy: 0.9914
# Epoch 46/50
# 30/30 - 0s - loss: 0.0312 - accuracy: 0.9957 - val_loss: 0.0503 - val_accuracy: 0.9914
# Epoch 47/50
# 30/30 - 0s - loss: 0.0312 - accuracy: 0.9957 - val_loss: 0.0472 - val_accuracy: 0.9914
# Epoch 48/50
# 30/30 - 0s - loss: 0.0316 - accuracy: 0.9957 - val_loss: 0.0596 - val_accuracy: 0.9914
# Epoch 49/50
# 30/30 - 0s - loss: 0.0318 - accuracy: 0.9957 - val_loss: 0.0502 - val_accuracy: 0.9914
# Epoch 50/50
# 30/30 - 0s - loss: 0.0301 - accuracy: 0.9957 - val_loss: 0.0467 - val_accuracy: 0.9914

# %%
# evaluate the model
scores = model.evaluate(X, Y)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0345 - accuracy: 0.9943
# accuracy: 99.43%
